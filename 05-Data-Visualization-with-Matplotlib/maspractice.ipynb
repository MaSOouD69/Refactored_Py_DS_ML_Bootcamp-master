# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a = np.linspace(0,12,25)

# %%
b = a ** 2
z = a*b

# %%
plt.plot(a,b)
plt.xlabel(" XxX")
plt.ylabel('YyY')
plt.title(" my firt fig")
# Out:
# Text(0.5, 1.0, ' my firt fig')

# %%
fig = plt.figure(figsize=(9,9))

axes1 = fig.add_axes([0,0,0.9,0.9])
axes2 = fig.add_axes([0.1,0.3,0.4,0.4])
axes3 = fig.add_axes([0.6,0.1,0.2,0.2])
axes1.plot(a,b,"r--", label="xxx")
axes1.plot(b,b/5,"b", label="test2")
axes1.set_xlabel(" XxX")
axes1.set_ylabel("YyY")
axes1.set_title("TtTtT")
axes1.legend()


axes2.plot(2*b,2/a,"b*")
y=list(range(10))
x=np.tan(y)
axes3.plot(x,y,"green")
axes3.legend(loc=0)
# Out:
# <ipython-input-14-35df8391a452>:14: RuntimeWarning: divide by zero encountered in true_divide
#   axes2.plot(2*b,2/a,"b*")
# No handles with labels found to put in legend.

# %%
fig.savefig("filename.png")
